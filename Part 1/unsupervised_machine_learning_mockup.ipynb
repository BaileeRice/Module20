# %%
import pandas as pd
import plotly.express as px
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
#adding connection string
from sqlalchemy import create_engine
from config import config
#adding connection string
engine = create_engine(f'postgresql://postgres:{config}@localhost:5432/Module20')

# %%
# Loading data
df_genre = pd.read_sql('SELECT * FROM master', engine)
df_genre.head(10)
# Out:
#    index                track_id                       track_name  \
# 0   2044  0017A6SJgTbfQVU2EtsPNo                         Pangarap
# 1   6158  002pvkf2wremlgx2bDgHjP                         Swingin'
# 2   4054  00aqkszH1FdUiJJWvX6iEl          Wicked Games - Original
# 3   4248  00Blm7zeNqgYLPtW6zg8cj  One Right Now (with The Weeknd)
# 4    874  00F4KTGb1WQ2zdaQA90sIT                     Sorry Anyway
# 5   3398  00fjo9x6qJTFwARfpQYijD  Country Stuff (feat. Jake Owen)
# 6   6229  00h3UmLzktuyywU2faS7os                              Lot
# 7   3610  00klSin5es2cwPgZf103Fz                  What Part of No
# 8   6491  00KWg3ywQZVELTUa1U2vsx   Bardziej Sobą Niż Kiedykolwiek
# 9   2575  00N5SEfWH4b3aQhVDGVv7M               Closer To Over You
#
#                 artist_id      artist_name                album_id  duration  \
# 0  2cUM0BKXb6AP3CQAYK7xOw  Barbie's Cradle  1srJQ0njEQgd8w4XSqI4JQ    235440
# 1  6qkf1bvT0H0Ytd87UOfwws        Luwidakid  3OUHHTFk1OqFzLugNmlEgO    165291
# ...

# %%
df_genre.dtypes
# Out:
# index                 int64
# track_id             object
# track_name           object
# artist_id            object
# artist_name          object
# album_id             object
# duration              int64
# release_date         object
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# playlist_id          object
# playlist_name        object
# genre                object
# dtype: object

# %% [markdown]
# # Building the KMeans Model

# %%
x = df_genre[['popularity', 'duration', 'mode', 'speechiness','acousticness','instrumentalness','liveness','valence','tempo']]

# %%
# Initializing model with K = 4 (since we already know there are four genres)
model = KMeans(n_clusters=4, random_state=5)
model
# Out:
# KMeans(n_clusters=4, random_state=5)

# %%
# Fitting model
model.fit(x)
# Out:
# KMeans(n_clusters=4, random_state=5)

# %%
# Get the predictions
predictions = model.predict(x)
print(predictions)
# Out:
# [1 3 0 ... 3 1 0]

# %%
# Add a new class column to the df
df_genre["class"] = model.labels_
df_genre.head()
# Out:
#    index                track_id                       track_name  \
# 0   2044  0017A6SJgTbfQVU2EtsPNo                         Pangarap
# 1   6158  002pvkf2wremlgx2bDgHjP                         Swingin'
# 2   4054  00aqkszH1FdUiJJWvX6iEl          Wicked Games - Original
# 3   4248  00Blm7zeNqgYLPtW6zg8cj  One Right Now (with The Weeknd)
# 4    874  00F4KTGb1WQ2zdaQA90sIT                     Sorry Anyway
#
#                 artist_id      artist_name                album_id  duration  \
# 0  2cUM0BKXb6AP3CQAYK7xOw  Barbie's Cradle  1srJQ0njEQgd8w4XSqI4JQ    235440
# 1  6qkf1bvT0H0Ytd87UOfwws        Luwidakid  3OUHHTFk1OqFzLugNmlEgO    165291
# 2  1Xyo4u8uXC1ZmMpatF05PJ       The Weeknd  7zCODUHkfuRxsUjtuzNqbd    325305
# 3  246dkjvS1zLTtiykXe5h60      Post Malone  6fgSKdHloRioPrZ9oJC7FH    193506
# 4  0dezZxuxgC2EKGhXk8IVI0      Sean Keefer  7FZfoIJgZ6j2cQuipAPcVc    239108
#
#   release_date  popularity  danceability  ...  speechiness  acousticness  \
# ...

# %%
df_genre['track_id'].value_counts()
# Out:
# 0017A6SJgTbfQVU2EtsPNo    1
# 5ad4erSBw23M9ZR9qXxKJO    1
# 5AnSllIrgGsCZzZJkVnApx    1
# 5ANnHcFKjGAC98A7Qkaepd    1
# 5anCkDvJ17aznvK5TED5uo    1
#                          ..
# 2lFtnEmkIPm2ClN55e2chV    1
# 2LfRxbEQMsqzkU1VpsuZrn    1
# 2LF0OpWDJDad3cNGqwk3kf    1
# 2lCGAGpqgQIolNfpnycIZk    1
# 7zzZmpw8L66ZPjH1M6qmOs    1
# Name: track_id, Length: 6027, dtype: int64

# %%
# Create a scatterplot of df_genre
df_genre.hvplot.scatter(x="track_id", y="genre", by="class")
# Out:
# :NdOverlay   [class]
#    :Scatter   [track_id]   (genre)

# %% [markdown]
# # PCA

# %%
#standardize data with standardscaler
genre_scaled = StandardScaler().fit_transform(x)
print(genre_scaled[0:5])
# Out:
# [[-0.54327728  0.33796748  0.72833531 -0.72872477  0.19404563 -0.1063721
#   -0.65204509  0.16057482 -0.83626376]
#  [-1.88118934 -0.87737915  0.72833531 -0.07929591 -0.64146807 -0.21403552
#   -0.46223978 -1.3659313   0.62195991]
#  [ 0.47169049  1.89489809  0.72833531 -0.65178256 -0.85309356 -0.2175102
#    0.88010961 -1.20618066 -0.26012921]
#  [ 1.85573745 -0.38854815  0.72833531 -0.45942705 -0.79448958 -0.21759071
#   -0.7473086   0.701952   -0.83888225]
#  [-1.05076116  0.40151638  0.72833531 -0.70307737  0.50334442 -0.21739774
#   -0.59719641  0.10732461  0.28308725]]

# %%
# Initialize PCA model
pca = PCA(n_components=3)

# %%
# Get principal components for the genre data.
genre_pca = pca.fit_transform(genre_scaled)

# %%
df_genre_pca = pd.DataFrame(
    data=genre_pca, columns=['principal component 1', 'principal component 2', 'principal component 3']
)
df_genre_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3
# 0               0.957327              -0.716660              -0.724287
# 1               0.636234              -0.191295              -0.073588
# 2               1.680511               0.734021               0.327122
# 3              -0.502523               0.147865              -1.261669
# 4               0.933472              -0.445593              -0.834378

# %%
# Add the predicted class columns
df_genre_pca["class"] = df_genre['genre']
df_genre_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3 class
# 0               0.957327              -0.716660              -0.724287  Rock
# 1               0.636234              -0.191295              -0.073588   Rap
# 2               1.680511               0.734021               0.327122   R&B
# 3              -0.502523               0.147865              -1.261669   R&B
# 4               0.933472              -0.445593              -0.834378  Rock

# %%
# Use explained_variance_ratio to learn how much information can be attributed to each principal component:
pca.explained_variance_ratio_
# Out:
# array([0.14535366, 0.13433904, 0.13029319])

# %%
# Plotting the clusters with three features
fig = px.scatter_3d(df_genre_pca, x="principal component 1", y="principal component 2", z="principal component 3", color='class', width=800)
fig.update_layout(legend=dict(x=0,y=1))
fig.show()
# Out:
# <div>                            <div id="8817c390-2c4d-4d7c-9356-7bc78e164aa6" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8817c390-2c4d-4d7c-9356-7bc78e164aa6")) {                    Plotly.newPlot(                        "8817c390-2c4d-4d7c-9356-7bc78e164aa6",                        [{"hovertemplate":"class=Rock<br>principal component 1=%{x}<br>principal component 2=%{y}<br>principal component 3=%{z}<extra></extra>","legendgroup":"Rock","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Rock","scene":"scene","showlegend":true,"x":[0.957326972582926,0.9334720509492173,1.2541958670757614,0.4766992946351621,0.9053931572486867,1.3265130906878442,-0.5107190429764059,0.012420813564737006,1.2774679093041126,-0.9560356320193173,
# ...

# %%
# Initializing model with K = 4 (since we already know there are three genres)
model = KMeans(n_clusters=4, random_state=5)
model
# Out:
# KMeans(n_clusters=4, random_state=5)

# %%
# Fitting model
model.fit(df_genre_pca[["principal component 1", "principal component 2", "principal component 3"]])
# Out:
# KMeans(n_clusters=4, random_state=5)

# %%
# Get the predictions
predictions = model.predict(df_genre_pca[["principal component 1", "principal component 2", "principal component 3"]])
print(predictions)
# Out:
# [0 0 3 ... 1 2 0]

# %%
# Add the predicted class columns
df_genre_pca["class_2"] = model.labels_
df_genre_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3 class  \
# 0               0.957327              -0.716660              -0.724287  Rock
# 1               0.636234              -0.191295              -0.073588   Rap
# 2               1.680511               0.734021               0.327122   R&B
# 3              -0.502523               0.147865              -1.261669   R&B
# 4               0.933472              -0.445593              -0.834378  Rock
#
#    class_2
# 0        0
# 1        0
# 2        3
# 3        2
# 4        0

# %%
fig = px.scatter_3d(df_genre_pca, x="principal component 1", y="principal component 2", z="principal component 3", color='class_2', width=800)
fig.update_layout(legend=dict(x=0,y=1))
fig.show()
# Out:
# <div>                            <div id="13bd30c7-de5b-4cbf-9c4c-65d338266761" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13bd30c7-de5b-4cbf-9c4c-65d338266761")) {                    Plotly.newPlot(                        "13bd30c7-de5b-4cbf-9c4c-65d338266761",                        [{"hovertemplate":"principal component 1=%{x}<br>principal component 2=%{y}<br>principal component 3=%{z}<br>class_2=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0,0,3,2,0,2,2,2,1,2,0,1,3,2,2,1,2,3,1,0,1,0,0,0,2,2,3,1,2,2,2,3,1,1,0,1,0,1,3,1,1,1,0,1,2,1,2,2,3,2,1,0,0,3,0,0,3,2,1,0,1,3,0,0,2,0,0,2,0,2,1,2,2,2,1,1,1,1,2,1,3,0,2,1,3,1,2,2,1,1,2,0,0,2,2,2,2,1,0,2,1,3,1,0,0,0,2,2,0,2,1,1,2,3,1,0,1,0,2,1,1,0,2,1,1,2,0,2,0,2,0,3,2,2,3,0,0,3,0,2,1,
# ...

# %%
df_genre["class(2)"] = model.labels_
df_genre
# Out:
#       index                track_id                       track_name  \
# 0      2044  0017A6SJgTbfQVU2EtsPNo                         Pangarap
# 1      6158  002pvkf2wremlgx2bDgHjP                         Swingin'
# 2      4054  00aqkszH1FdUiJJWvX6iEl          Wicked Games - Original
# 3      4248  00Blm7zeNqgYLPtW6zg8cj  One Right Now (with The Weeknd)
# 4       874  00F4KTGb1WQ2zdaQA90sIT                     Sorry Anyway
# ...     ...                     ...                              ...
# 6022   2208  7zVCrzzEJU7u24sbJPXA5W   What Ifs (feat. Lauren Alaina)
# 6023   2676  7zwi0kPSFtdNUNIXZlKfNF            Shakin' In Them Boots
# 6024   6457  7zxRMhXxJMQCeDDg0rKAVo                         Some Way
# 6025   3395  7zxsnW2mjKjpkgvfZqQNX4         Some Things Never Change
# 6026   2008  7zzZmpw8L66ZPjH1M6qmOs                         Migraine
#
#                    artist_id       artist_name                album_id  \
# ...
