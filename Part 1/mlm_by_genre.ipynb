# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt

# Import PCA from sci-kit learn
from sklearn.decomposition import PCA
import hvplot.pandas

# %%
rock_df = pd.read_csv('../Resources/rock_playlist_tracks_data.csv')
rock_df.head()
# Out:
#    Unnamed: 0                track_id  \
# 0           0  57JVGBtBLCfHw2muk5416J
# 1           1  57JVGBtBLCfHw2muk5416J
# 2           2  57JVGBtBLCfHw2muk5416J
# 3           3  57JVGBtBLCfHw2muk5416J
# 4           4  2zYzyRzz6pRmhPzyfMEC8s
#
#                                      track_name               artist_id  \
# 0  Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 1  Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 2  Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 3  Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 4                               Highway to Hell  711MCceyCBcFnzjGY4Q7Un
#
#   artist_name                album_id  duration release_date  popularity  \
# 0       Queen  6wPXUmYJ9mOWrKlLzZ5cCa    214653   1980-06-27          74
# 1       Queen  6wPXUmYJ9mOWrKlLzZ5cCa    214653   1980-06-27          74
# 2       Queen  6wPXUmYJ9mOWrKlLzZ5cCa    214653   1980-06-27          74
# ...

# %%
rock_df['Genre'] = 'Rock'

# %%
rap_df = pd.read_csv('../Resources/rap_playlist_tracks_data.csv')
rap_df.head()
# Out:
#                  track_id                            track_name  \
# 0  48qgXl0CQUVYJVn6xv0rsP                       Nothing Changed
# 1  6mM8gri8d2abYYomjOV4ut                        Stop Breathing
# 2  5tzEcVk8jFSBhTrO0ZYJdZ                        I’m So Awesome
# 3  5uVW9FWVaQde0lfF4hYs4C             CODE (feat. Moneybagg Yo)
# 4  2BSl2gSFHdzJAMus74qzNj  Backstage Passes (feat. Jack Harlow)
#
#                 artist_id  artist_name                album_id  duration  \
# 0  0VRj0yCOv2FXJNP47XQnx5        Quavo  4Lo6GJMW4ctfhtuCqMkn1O    199111
# 1  757aE44tKEUQEqRuT6GnEB  Roddy Ricch  1nP2b8dTaVUvvAOyRbDoBe    110706
# 2  46SHBwWsqBkxI7EeeBEQG7  Kodak Black  4D0WwN3ZWPdVqGLYRQw7pd    187202
# 3  4DdkRBBYG6Yk9Ka8tdJ9BW       Offset  42jB9RVqk28zOVbbKhSMX1    192427
# 4  4FlG0V0jhLO4qGpayFOphj      EST Gee  0A4xJz6OAedAQGriJH7pjn    158431
#
#   release_date  popularity  danceability  energy  ...  loudness  mode  \
# ...

# %%
rap_df['Genre'] = 'Rap'

# %%
rb_df = pd.read_csv('../Resources/rb_playlist_tracks_data.csv')
rb_df.head()
# Out:
#    Unnamed: 0                track_id                              track_name  \
# 0           0  2c7huQpWR29bcXrrvLcG2j  We Need A Resolution (feat. Timbaland)
# 1           1  0ceeRNqbOzRiGE42KWSrRa               Into You (feat. Fabolous)
# 2           2  4iuNZTcvT9diFySSzVsnVS                            When I See U
# 3           3  4iuNZTcvT9diFySSzVsnVS                            When I See U
# 4           4  2RqZFOLOnzVmHUX7ZMcaES                               Let It Go
#
#                 artist_id   artist_name                album_id  duration  \
# 0  0urTpYCsixqZwgNTkPJOJ4       Aaliyah  0cNaDPtbHC1PMJMRTY2GFc    242826
# 1  0le01dl1WllSHhjEXRl4in         Tamia  43QuYbSfbTjcsghwJyUnyP    294093
# 2  7xAcVHPiirnUqfdqo0USb1      Fantasia  42DybH3gl3WcfXAQySOEiX    217346
# 3  7xAcVHPiirnUqfdqo0USb1      Fantasia  42DybH3gl3WcfXAQySOEiX    217346
# 4  1vfezMIyCr4XUdYRaKIKi3  Keyshia Cole  7mdy09EO4q6F9VWBtXDDjK    238333
#
# ...

# %%
rb_df['Genre'] = 'R&B'

# %%
country_df = pd.read_csv('../Resources/country_playlist_tracks_data.csv')
country_df.head()
# Out:
#                  track_id                  track_name               artist_id  \
# 0  0BkzrrQUzJhCAFk3Pq7g29                   Hell Yeah  3CygdxquGHurS7f9LjNLkv
# 1  6HBRLaSQ7NB8MNlaqzYen1  What My World Spins Around  77kULmXAQ6vWer7IIHdGzI
# 2  4tKtMWS8LZRvWhzuHKRIdr    I Can't Love You Anymore  6WY7D3jk8zTrHtmkqqo5GI
# 3  28n8z9IQKyjMPxmvYMBqZa    The Kind of Love We Make  718COspgdWOnwOFpJHRZHS
# 4  4iy69rTUn8cAY8Q8q9vfOw                        Gold  7x8nK0m0cP2ksQf0mjWdPS
#
#        artist_name                album_id  duration release_date  popularity  \
# 0  Little Big Town  0IqcqqXBaXwUx1IV2jHb6I    175840   2022-04-11          68
# 1     Jordan Davis  4oTrQ9TmOapgT6uI8W6wsS    186790   2022-05-27          78
# 2     Maren Morris  3BEDHGAd2zJh5dUL4dbmiw    169306   2022-03-25          66
# 3       Luke Combs  77B78XJKo4LcsrRg34GNTu    224426   2022-06-17          82
# 4   Dierks Bentley  2NLp3E2m7Z9JnoLR6eOJYI    167760   2022-07-29          62
#
# ...

# %%
country_df['Genre'] = 'Country'

# %%
# merge df's
df = pd.concat([rock_df, country_df, rb_df, rap_df])
df.reset_index(inplace=True)
df
# Out:
#       index  Unnamed: 0                track_id  \
# 0         0         0.0  57JVGBtBLCfHw2muk5416J
# 1         1         1.0  57JVGBtBLCfHw2muk5416J
# 2         2         2.0  57JVGBtBLCfHw2muk5416J
# 3         3         3.0  57JVGBtBLCfHw2muk5416J
# 4         4         4.0  2zYzyRzz6pRmhPzyfMEC8s
# ...     ...         ...                     ...
# 6506   1456         NaN  2YV92JPqrmVufFIAN4hqIF
# 6507   1457         NaN  4cI4UJf0z14rwM4IYlwVFF
# 6508   1458         NaN  54NQP70Bn4nAspwZODu732
# 6509   1459         NaN  7sjusRh3o5hBulm8qj6t60
# 6510   1460         NaN  5AbV01SCRrjQFAsLoVR0ZN
#
#                                         track_name               artist_id  \
# 0     Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 1     Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 2     Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 3     Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# ...

# %%
#removing unneccesary columns
df.pop('Unnamed: 0')
df.head()
# Out:
#    index                track_id  \
# 0      0  57JVGBtBLCfHw2muk5416J
# 1      1  57JVGBtBLCfHw2muk5416J
# 2      2  57JVGBtBLCfHw2muk5416J
# 3      3  57JVGBtBLCfHw2muk5416J
# 4      4  2zYzyRzz6pRmhPzyfMEC8s
#
#                                      track_name               artist_id  \
# 0  Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 1  Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 2  Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 3  Another One Bites The Dust - Remastered 2011  1dfeR4HaWDbWqFHLkxsg1d
# 4                               Highway to Hell  711MCceyCBcFnzjGY4Q7Un
#
#   artist_name                album_id  duration release_date  popularity  \
# 0       Queen  6wPXUmYJ9mOWrKlLzZ5cCa    214653   1980-06-27          74
# 1       Queen  6wPXUmYJ9mOWrKlLzZ5cCa    214653   1980-06-27          74
# 2       Queen  6wPXUmYJ9mOWrKlLzZ5cCa    214653   1980-06-27          74
# ...

# %%
#removing unneccesary columns
df.pop('index')
df.head()
# Out:
#                  track_id                                    track_name  \
# 0  57JVGBtBLCfHw2muk5416J  Another One Bites The Dust - Remastered 2011
# 1  57JVGBtBLCfHw2muk5416J  Another One Bites The Dust - Remastered 2011
# 2  57JVGBtBLCfHw2muk5416J  Another One Bites The Dust - Remastered 2011
# 3  57JVGBtBLCfHw2muk5416J  Another One Bites The Dust - Remastered 2011
# 4  2zYzyRzz6pRmhPzyfMEC8s                               Highway to Hell
#
#                 artist_id artist_name                album_id  duration  \
# 0  1dfeR4HaWDbWqFHLkxsg1d       Queen  6wPXUmYJ9mOWrKlLzZ5cCa    214653
# 1  1dfeR4HaWDbWqFHLkxsg1d       Queen  6wPXUmYJ9mOWrKlLzZ5cCa    214653
# 2  1dfeR4HaWDbWqFHLkxsg1d       Queen  6wPXUmYJ9mOWrKlLzZ5cCa    214653
# 3  1dfeR4HaWDbWqFHLkxsg1d       Queen  6wPXUmYJ9mOWrKlLzZ5cCa    214653
# 4  711MCceyCBcFnzjGY4Q7Un       AC/DC  10v912xgTZbjAtYfyKWJCS    208400
#
#   release_date  popularity  danceability  energy  ...  mode  speechiness  \
# ...

# %%
#checking for duplicates
len(df['track_id'].unique())
# Out:
# 6027

# %%
duplicates_df = df.drop_duplicates(subset=['track_id', 'Genre'])
duplicates_df[['track_id', 'track_name']].value_counts().head(30)
# Out:
# track_id                track_name
# 1VLtjHwRWOVJiE5Py7JxoQ  Martin & Gina                                2
# 12ejw7TyhQU6uODWEaDLFt  Quantas Vezes?                               2
# 2JvzF1RMd7lE3KmFlsyZD8  MIDDLE CHILD                                 2
# 35RJhm1pEovTBwnNR0zWad  GREECE (feat. Drake)                         2
# 5rZlwNFl01HqLWBQGryKSm  Mood Swings (feat. Lil Tjay)                 2
# 4XvcHTUfIlWfyJTRG0aqlo  2055                                         2
# 2wAJTrFhCnQyNSD3oUgTZO  Work Out                                     2
# 1MIGkQxcdAt2lDx6ySpsc5  SUVs (Black on Black)                        2
# 7hxHWCCAIIxFLCzvDgnQHX  Lemonade (feat. Gunna, Don Toliver & NAV)    2
# 1H7KnK26kc1YyellpbINEn  The Woo (feat. 50 Cent & Roddy Ricch)        2
# 4nva9EpKntUTs6CRSGBCn9  Just A Lil Bit                               2
# 5yY9lUy8nbvjM1Uyo1Uqoc  Life Is Good (feat. Drake)                   2
# 1IIKrJVP1C9N7iPtG6eOsK  Go Crazy                                     2
# ...

# %%
duplicates_df[duplicates_df['track_name']== 'MIDDLE CHILD']
# Out:
#                     track_id    track_name               artist_id  \
# 5037  2JvzF1RMd7lE3KmFlsyZD8  MIDDLE CHILD  6l3HvQ5sa6mXTsMTB19rO5
# 5614  2JvzF1RMd7lE3KmFlsyZD8  MIDDLE CHILD  6l3HvQ5sa6mXTsMTB19rO5
#
#      artist_name                album_id  duration release_date  popularity  \
# 5037     J. Cole  3XzSOIE6zGLliuqsVGLmUc    213593   2019-01-23          81
# 5614     J. Cole  3XzSOIE6zGLliuqsVGLmUc    213593   2019-01-23          81
#
#       danceability  energy  ...  mode  speechiness  acousticness  \
# 5037         0.837   0.364  ...     1        0.276         0.149
# 5614         0.837   0.364  ...     1        0.276         0.149
#
#       instrumentalness  liveness  valence    tempo             playlist_id  \
# 5037               0.0     0.271    0.463  123.984  37i9dQZF1DX3ORvAIr1RbU
# 5614               0.0     0.271    0.463  123.984  4riovLwMCrY3q0Cd4e0Sqp
#
#                playlist_name Genre
# 5037        Hip Hop + R&B FM   R&B
# ...

# %%
new_rock_df = duplicates_df[duplicates_df['Genre']== 'Rock']
new_rock_df.head()
# Out:
#                   track_id                                    track_name  \
# 0   57JVGBtBLCfHw2muk5416J  Another One Bites The Dust - Remastered 2011
# 4   2zYzyRzz6pRmhPzyfMEC8s                               Highway to Hell
# 8   3YBZIN3rekqsKxbJc9FZko                                 Paradise City
# 12  39shmbIHICJ2Wxnk1fPSdz     Should I Stay or Should I Go - Remastered
# 16  2Cdvbe2G4hZsnhNMKyGrie                           I Love Rock 'N Roll
#
#                  artist_id                  artist_name  \
# 0   1dfeR4HaWDbWqFHLkxsg1d                        Queen
# 4   711MCceyCBcFnzjGY4Q7Un                        AC/DC
# 8   3qm84nBOXUEQ2vnTfUTTFC                Guns N' Roses
# 12  3RGLhK1IP9jnYFH4BRFJBS                    The Clash
# 16  1Fmb52lZ6Jv7FMWXXTPO3K  Joan Jett & The Blackhearts
#
#                   album_id  duration release_date  popularity  danceability  \
# 0   6wPXUmYJ9mOWrKlLzZ5cCa    214653   1980-06-27          74         0.933
# ...

# %%
new_rap_df = duplicates_df[duplicates_df['Genre']== 'Rap']
new_rap_df.head()
# Out:
#                     track_id                            track_name  \
# 5050  48qgXl0CQUVYJVn6xv0rsP                       Nothing Changed
# 5051  6mM8gri8d2abYYomjOV4ut                        Stop Breathing
# 5052  5tzEcVk8jFSBhTrO0ZYJdZ                        I’m So Awesome
# 5053  5uVW9FWVaQde0lfF4hYs4C             CODE (feat. Moneybagg Yo)
# 5054  2BSl2gSFHdzJAMus74qzNj  Backstage Passes (feat. Jack Harlow)
#
#                    artist_id  artist_name                album_id  duration  \
# 5050  0VRj0yCOv2FXJNP47XQnx5        Quavo  4Lo6GJMW4ctfhtuCqMkn1O    199111
# 5051  757aE44tKEUQEqRuT6GnEB  Roddy Ricch  1nP2b8dTaVUvvAOyRbDoBe    110706
# 5052  46SHBwWsqBkxI7EeeBEQG7  Kodak Black  4D0WwN3ZWPdVqGLYRQw7pd    187202
# 5053  4DdkRBBYG6Yk9Ka8tdJ9BW       Offset  42jB9RVqk28zOVbbKhSMX1    192427
# 5054  4FlG0V0jhLO4qGpayFOphj      EST Gee  0A4xJz6OAedAQGriJH7pjn    158431
#
#      release_date  popularity  danceability  energy  ...  mode  speechiness  \
# ...

# %%
new_rb_df = duplicates_df[duplicates_df['Genre']== 'R&B']
new_rb_df.head()
# Out:
#                     track_id  \
# 3672  2c7huQpWR29bcXrrvLcG2j
# 3673  0ceeRNqbOzRiGE42KWSrRa
# 3674  4iuNZTcvT9diFySSzVsnVS
# 3676  2RqZFOLOnzVmHUX7ZMcaES
# 3677  6nTcn8CybBcx0t7IaXEJ6O
#
#                                              track_name  \
# 3672             We Need A Resolution (feat. Timbaland)
# 3673                          Into You (feat. Fabolous)
# 3674                                       When I See U
# 3676                                          Let It Go
# 3677  Thank God I Found You (feat. Joe & Nas) - Make...
#
#                    artist_id   artist_name                album_id  duration  \
# 3672  0urTpYCsixqZwgNTkPJOJ4       Aaliyah  0cNaDPtbHC1PMJMRTY2GFc    242826
# 3673  0le01dl1WllSHhjEXRl4in         Tamia  43QuYbSfbTjcsghwJyUnyP    294093
# 3674  7xAcVHPiirnUqfdqo0USb1      Fantasia  42DybH3gl3WcfXAQySOEiX    217346
# 3676  1vfezMIyCr4XUdYRaKIKi3  Keyshia Cole  7mdy09EO4q6F9VWBtXDDjK    238333
# ...

# %%
new_country_df = duplicates_df[duplicates_df['Genre']== 'Country']
new_country_df.head()
# Out:
#                     track_id                  track_name  \
# 2131  0BkzrrQUzJhCAFk3Pq7g29                   Hell Yeah
# 2132  6HBRLaSQ7NB8MNlaqzYen1  What My World Spins Around
# 2133  4tKtMWS8LZRvWhzuHKRIdr    I Can't Love You Anymore
# 2134  28n8z9IQKyjMPxmvYMBqZa    The Kind of Love We Make
# 2135  4iy69rTUn8cAY8Q8q9vfOw                        Gold
#
#                    artist_id      artist_name                album_id  \
# 2131  3CygdxquGHurS7f9LjNLkv  Little Big Town  0IqcqqXBaXwUx1IV2jHb6I
# 2132  77kULmXAQ6vWer7IIHdGzI     Jordan Davis  4oTrQ9TmOapgT6uI8W6wsS
# 2133  6WY7D3jk8zTrHtmkqqo5GI     Maren Morris  3BEDHGAd2zJh5dUL4dbmiw
# 2134  718COspgdWOnwOFpJHRZHS       Luke Combs  77B78XJKo4LcsrRg34GNTu
# 2135  7x8nK0m0cP2ksQf0mjWdPS   Dierks Bentley  2NLp3E2m7Z9JnoLR6eOJYI
#
#       duration release_date  popularity  danceability  energy  ...  mode  \
# 2131    175840   2022-04-11          68         0.577   0.601  ...     1
# ...

# %%
#create new CSV
duplicates_df.to_csv('dropped_duplicates_df.csv')
new_rock_df.to_csv('../Resources/new_rock_df.csv')
new_rap_df.to_csv('../Resources/new_rap_df.csv')
new_rb_df.to_csv('../Resources/new_rb_df.csv')
new_country_df.to_csv('../Resources/new_country_df.csv')
